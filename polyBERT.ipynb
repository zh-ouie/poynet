# %%
from model_prediction import ModelPredictor
import pandas as pd
# 加载模型
predictor = ModelPredictor('trained_models/attention_20C_all/model.pth')

# 单个预测
# prediction = predictor.predict_single(
#     smiles="C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)O)O[Na].C(=C)O",
#     material_properties={
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         }
# )
# print(f"Single prediction: {prediction:.6f}")
#批量预测
#PVA-SA
# predictions = predictor.predict_batch(
#     smiles_list=[
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)O)O[Na].C(=C)O", 
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@H](O1)OC=C)O)O)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@](O)(O1)C=C)O)O)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)OC=C)O)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@]([C@@H](O)O1)(O)C=C)O)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)OC=C)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@]([C@@H]([C@@H](O)O1)O)(O)C=C)O)O[Na]",
#         "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)OC=C)O[Na]",
#         "C(=O)([C@H]1[C@@]([C@@H]([C@@H]([C@@H](O)O1)O)O)(O)C=C)O[Na]",
#         "C(=O)([C@]1([C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)O)CC)O[Na]"
#     ],
#     material_properties_list=[
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,
#             'ElongationatBreak': 190.7,
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,
#             'ElongationatBreak': 190.7,
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,
#             'ElongationatBreak': 190.7,
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,
#             'ElongationatBreak': 190.7,
#             'TensileStrength': 0.75             # 添加拉伸强度
#         },
#         {
#             'WaterContent': 89.3, 
#             'SwellingRate': 143.6,
#             'Degreeofpolymerization': 1750,  # 添加聚合度
#             'ElongationatBreak': 190.7,         # 添加断裂伸长率
#             'TensileStrength': 0.75             # 添加拉伸强度
#         }
#     ]
# )
#PVA-AA
# predictions = predictor.predict_batch(
#     smiles_list=[
#         "C(=O)(O)C=C.C(=C)O", 
#         "C(=O)(OC=C)C=C",
#         "C(=O)(O)C(=C)C=C",
#         "C(=O)(O)CCCC",
#         "C(=O)(O)/C=C/C=C"
#     ],
#     material_properties_list=[
#         {
#             'WaterContent': 90.3, 
#             'SwellingRate': 194.1,
#             'Degreeofpolymerization': 1750,  
#             'ElongationatBreak': 120.3,         
#             'TensileStrength': 0.43            
#         },
#         {
#             'WaterContent': 90.3, 
#             'SwellingRate': 194.1,
#             'Degreeofpolymerization': 1750,  
#             'ElongationatBreak': 120.3,         
#             'TensileStrength': 0.43            
#         },
#         {
#             'WaterContent': 90.3, 
#             'SwellingRate': 194.1,
#             'Degreeofpolymerization': 1750,  
#             'ElongationatBreak': 120.3,         
#             'TensileStrength': 0.43            
#         },
#         {
#             'WaterContent': 90.3, 
#             'SwellingRate': 194.1,
#             'Degreeofpolymerization': 1750,  
#             'ElongationatBreak': 120.3,         
#             'TensileStrength': 0.43            
#         },
#         {
#             'WaterContent': 90.3, 
#             'SwellingRate': 194.1,
#             'Degreeofpolymerization': 1750,  
#             'ElongationatBreak': 120.3,         
#             'TensileStrength': 0.43            
#         }
        
#     ]
# )
#PAM-SA
predictions = predictor.predict_batch(
    smiles_list=[
        "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)O)O[Na].C(=O)(C=C)N", 
        "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@H](O1)OC(=O)C=C)O)O)O)O[Na]",
        "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)OC(=O)C=C)O)O)O[Na]",
        "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)OC(=O)C=C)O)O[Na]",
        "C(=O)([C@H]1[C@@H]([C@@H]([C@@H]([C@@H](O)O1)O)O)OC(=O)C=C)O[Na]"
    ],
    material_properties_list=[
        {
            'WaterContent': 86.1, 
            'SwellingRate': 234.6,
            'Degreeofpolymerization': 5000,  
            'ElongationatBreak': 121.8,         
            'TensileStrength': 0.24            
        },
        {
            'WaterContent': 86.1, 
            'SwellingRate': 234.6,
            'Degreeofpolymerization': 5000,  
            'ElongationatBreak': 121.8,         
            'TensileStrength': 0.24            
        },
        {
            'WaterContent': 86.1, 
            'SwellingRate': 234.6,
            'Degreeofpolymerization': 5000,  
            'ElongationatBreak': 121.8,         
            'TensileStrength': 0.24            
        },
        {
            'WaterContent': 86.1, 
            'SwellingRate': 234.6,
            'Degreeofpolymerization': 5000,  
            'ElongationatBreak': 121.8,         
            'TensileStrength': 0.24            
        },
        {
            'WaterContent': 86.1, 
            'SwellingRate': 234.6,
            'Degreeofpolymerization': 5000,  
            'ElongationatBreak': 121.8,         
            'TensileStrength': 0.24            
        }
        
    ]
)
print("Batch predictions:")
for i, pred in enumerate(predictions):
    print(f"Prediction {i+1}: {pred:.6f}")
# 创建只包含预测结果的DataFrame
df_results = pd.DataFrame({
    'Predicted_Conductivity': predictions
})

filename = f'prediction_results.xlsx'

# 保存到Excel
df_results.to_excel(filename, index=False)
# Out:
# Using device: cpu
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Loading model from: trained_models/attention_20C_all/model.pth
# Model type: attention
# polyBERT dimension: 600
# Material dimension: 5
# Material features: ['WaterContent', 'SwellingRate', 'Degreeofpolymerization', 'ElongationatBreak', 'TensileStrength']
# Loaded feature scaler from: trained_models/attention_20C_all/feature_scaler.pkl
# ✅ Model loaded successfully!
# Batch predictions:
# Prediction 1: 34.204372
# Prediction 2: 29.796749
# Prediction 3: 31.949295
# Prediction 4: 33.059444
# Prediction 5: 32.200214
